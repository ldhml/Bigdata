# %% [markdown]
# <a href="https://colab.research.google.com/github/ldhml/Bigdata/blob/main/bigdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
f=open('/content/seoul.csv', 'r',encoding='cp949')
data=csv.reader(f)
header=next(data)

for row in data:
  print(row)

f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-70095a29a22f> in <module>()
#       1 import csv
# ----> 2 f=open('/content/seoul.csv', 'r',encoding='cp949')
#       3 data=csv.reader(f)
#       4 header=next(data)
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/seoul.csv'

# %%
import csv
f=open('seoul.csv', 'r',encoding='cp949')
data=csv.reader(f)
header=next(data)
max_temp=-999
max_date=''
for row in data:
  if row[-1]=='':
    row[-1]=-999
  row[-1]=float(row[-1])
  if max_temp<row[-1]:
    max_date=row[0]
    max_temp=row[-1]
f.close()
print('기상 관측 이래 서울의 최고 기온이 가장 높았던 날은',max_date+'로,',max_temp,'도 였습니다.')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-424476c58cb8> in <module>()
#       1 import csv
# ----> 2 f=open('seoul.csv', 'r',encoding='cp949')
#       3 data=csv.reader(f)
#       4 header=next(data)
#       5 max_temp=-999
#
# FileNotFoundError: [Errno 2] No such file or directory: 'seoul.csv'

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[12,43,25,15])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.title('color') #제목 설정
#그래프 그리기
plt.plot([10,20,30,40],color='green',label='green')
plt.plot([40,30,20,10],'yellow',label='yellow')
plt.legend() #범례표시
plt.show()

# %%
import matplotlib.pyplot as plt
plt.title('marker')
plt.plot([10,20,30,40],'r.',label='circle')

plt.plot([40,30,20,10],'g^',label='triangle up')
plt.legend()
plt.show()

# %%
import csv
f=open('seoul.csv','r',encoding='cp949')
data=csv.reader(f)
header=next(data)
result=[] # 최고 기온 데이터를 저장할 리스트 생성

for row in data:
  if row[-1]!='': #최고 기온 데이터 값이 존재한다면
    result.append(float(row[-1])) #result 리스트에 최고 기온 값 추가
print(result)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-451261b1d6fc> in <module>()
#       1 import csv
# ----> 2 f=open('seoul.csv','r',encoding='cp949')
#       3 data=csv.reader(f)
#       4 header=next(data)
#       5 result=[] # 최고 기온 데이터를 저장할 리스트 생성
#
# FileNotFoundError: [Errno 2] No such file or directory: 'seoul.csv'

# %%
import csv
import matplotlib.pyplot as plt
f=open('seoul.csv','r',encoding='cp949')
data=csv.reader(f)
header=next(data)
result=[] 
for row in data:
  if row[-1]!='':
    result.append(float(row[-1]))
plt.plot(result,'r') #result 리스트에 저장된 값을 빨간색 그래프로 그리기
plt.show() #그래프 나타내기

# %%
for row in data:
  if row[-1]!='':
    if row[0].split('-')[1]=='08':
      result.append(float(row[-1]))
plt.plot(result,'hotpink')
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f=open('/content/seoul.csv','r',encoding='cp949')
data=csv.reader(f)
next(data)
high=[]
low=[]

for row in data:
  if row[-1]!='' and row[-2]!='':
    if row[0].split('-')[1]=='02'and row[0].split('-')[2]=='14':
      high.append(float(row[-1]))
      low.append(float(row[-2]))

plt.plot(high,'hotpink')
plt.plot(low,'skyblue')
plt.show()

# %%
import csv
import matplotlib.pyplot as plt
 
f = open('seoul.csv','r',encoding='cp949')
data = csv.reader(f)
next(data)
 
aug = []                          
jan = []                          

for row in data :
    month = row[0].split('-')[1]  
    if row[-1] != '' :
        if month == '08':               
            aug.append(float(row[-1]))  
        if month == '01':               
            jan.append(float(row[-1]))  

plt.hist(aug, bins=100, color ='r', label='Aug')
plt.hist(jan, bins=100, color ='b', label='Jan')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
f = open('seoul.csv','r',encoding='cp949')
data = csv.reader(f)
next(data)
month = [[],[],[],[],[],[],[],[],[],[],[],[]]

for row in data :
    if row[-1] != '':
        month[int(row[0].split('-')[1])-1].append(float(row[-1]))
plt.boxplot(month)
plt.show()

# %%
import csv
f=open('/content/age.csv','r',encoding='cp949')
data=csv.reader(f)
result=[]

for row in data:
  if '신도림' in row[0]:
    for i in row[3:]:
      result.append(i)
print(result)

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.plot(result)
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f=open('age.csv','r',encoding='cp949')
data=csv.reader(f)
result=[]

name=input('원하는 동은?')

for row in data:
  if name in row[0]:
    for i in row[3:]:
      result.append(int(i))

plt.style.use('ggplot')
plt.plot(result)
plt.show()

# %%
import csv
f=open('age.csv','r',encoding='cp949')
data=csv.reader(f)

result=[]
for row in data:
  if '신도림' in row[0]:
    for i in row[3:]:
      result.append(int(i))

import matplotlib.pyplot as plt
plt.bar(range(101),result)
plt.show()

# %%
import csv
f=open('gender.csv','r',encoding='cp949')
data=csv.reader(f)
m=[]
f=[]
for row in data:
  if'신도림'in row[8]:
    m.append(int(row[i+3]))
    f.append(int(row[-(i+1)]))
f.reverse()

# %%
for row in data:
  if'신도림'in row[0]:
    for i in range(0,101):
    m.append(-int(row[i+3]))
    f.append(int(row[-(i+1)]))
f.reverse()

import matplotlib.pyplot as plt
plt.title('Gender Distribution in Sindorim')
plt.rcParams['axes.unicode_minus']=False
plt.barh(range(101),m,label='male')
plt.barh(range(101),f,label='female')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
size=[1000,1200,500,600]
label=['A','B','AB','O']
color=['magenta','deeppink','hotpink','pink']
plt.axis('equal')

plt.pie(size, labels=label,autopct='%.1f%%',colors=color,explode=(0,0,0.1,0))
plt.legend()
plt.show()

# %%
#우리동네인구 남/녀 비중을 보기 위해 누적연산 수행
import csv
import matplotlib.pyplot as plt
f=open('/content/gender.csv','r',encoding='cp949')
data=csv.reader(f)
size=[]
m = f = 0

for row in data:
  if'신도림'in row[0]:
    for i in range(0,101):
      m+=int(row[i+3])
      f+=int(row[-(i+1)])

size.append(m)
size.append(f)

color=['magenta','cyan']
plt.title('Gender Distribution in Sindorim')
plt.axis('equal')
plt.pie(size,labels=['M','F'],autopct='%.1f%%',colors=color)
plt.show()

# %%
#성별 연령별 인구 데이터 꺾은선 그래프로
import csv
import matplotlib.pyplot as plt
f=open('/content/gender.csv','r',encoding='cp949')
data=csv.reader(f)
m=[]
f=[]
name=input('원하는 동 입력: ')

for row in data:
  if name in row[0]:
    for i in range(3,104):
      m.append(int(row[i].replace(",","")))
      f.append(int(row[i+103].replace(",","")))
    break
plt.plot(m,label='Male')
plt.plot(f,label='Female')
plt.legend()
plt.show()

# %%
#연령별 '남성인구-여성인구' 막대그래프로
import csv
import matplotlib.pyplot as plt

f=open('/content/gender.csv','r',encoding='cp949')
data=csv.reader(f)
result=[]
name=input('원하는 동 입력: ')

for row in data:
  if name in row[0]:
    for i in range(3,104):
      result.append(int(row[i].replace(",",""))-int(row[i+103].replace(",","")))
    break

plt.bar(range(101),result)
plt.show()

# %%
#산점도로 표현하기 
import matplotlib.pyplot as plt
plt.scatter([1,2,3,4],[10,30,20,40])
plt.show()

# %%
#버블차트로 표현하기
#s=size
import matplotlib.pyplot as plt
plt.scatter([1,2,3,4],[10,30,20,40],s=[100,200,250,300])
plt.show()

# %%
#버블차트로 표현하기(색상추가)
#c=color
import matplotlib.pyplot as plt
plt.scatter([1,2,3,4],[10,30,20,40],s=[30,60,90,120],c=range(4))
plt.colorbar()
plt.show()

# %%
#버블차트로 표현하기(컬러바 추가)
#cmap 이라는 컬러맵 속서을 사용하면 컬러바에 사용될 색상의 종류를 선택 가능
#무지개색과 비슷한 jet컬러맵 사용
import matplotlib.pyplot as plt
plt.scatter([1,2,3,4],[10,30,20,40],s=[30,60,90,120],c=range(4),cmap='jet')
plt.colorbar()
plt.show()

# %%
#버블차트로 위치, 크기가 서로 다른 100개의 점 만들기
import matplotlib.pyplot as plt
import random
x=[]
y=[]
size=[]
for i in range(100):
  x.append(random.randint(50,100))
  y.append(random.randint(50,100))
  size.append(random.randint(10,100))
plt.scatter(x,y,s=size,c=range(100),cmap='jet',alpha=0.7)
plt.colorbar()
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f=open('/content/gender.csv','r',encoding='cp949')
data=csv.reader(f)
m=[]
f=[]
name=input('원하는 동 입력: ')

for row in data:
  if name in row[0]:
    for i in range(3,104):
      m.append(int(row[i].replace(",","")))
      f.append(int(row[i+103].replace(",","")))
    break
plt.scatter(m,f)
plt.show()

# %%
plt.scatter(m,f,c=range(101),alpha=0.5,cmap='jet')
plt.colorbar()
plt.plot(range(max(m)),range(max(m)),'g')
plt.show()

# %%
#연령대별 성별 비율 산점도로 표현하기(원의 크기는 인구수의 제곱근)하기
import csv
import math
import matplotlib.pyplot as plt

f=open('/content/gender.csv','r',encoding='cp949')
data=csv.reader(f)
m=[]
f=[]
size=[]
name=input('원하는 동 입력: ')

for row in data:
  if name in row[0]:
    for i in range(3,104):
      temp1=int(row[i].replace(",",""))
      temp2=int(row[i+103].replace(",",""))
      m.append(temp1)
      f.append(temp2)
      size.append(math.sqrt(temp1+temp2))
    break
plt.style.use('ggplot')
plt.figure(figsize=(10,5),dpi=300)
plt.scatter(m,f,s=size,c=range(101),alpha=0.5,cmap='jet')
plt.colorbar()
plt.plot(range(max(m)),range(max(m)),'g')
plt.xlabel('Male population')
plt.ylabel('Female population')
plt.show()

# %%
import csv
file=open('/content/sample_data/subwayfree.csv','r',encoding='cp949')
data=csv.reader(file)

for row in data:
  print(row)

# %%
#인원 숫자 데이터 정수로
import csv
file=open('/content/sample_data/subwayfree.csv','r',encoding='cp949')
data=csv.reader(file)
next(data)

for row in data:
  for i in range(4,8):
    row[i]=int(row[i])
  print(row)

# %%
import csv
file=open('/content/sample_data/subwayfree.csv','r',encoding='cp949')
data=csv.reader(file)
next(data)

mx=-1
rate=0

for row in data:
  for i in range(4,8):
    row[i]=int(row[i])
  if(row[6]==0):
    continue
  rate=row[4]/row[6]
  if rate > mx:
    mx=rate

  print(mx)

# %%
#승차인원이 최대인 역을 찾고 그 값을 찾아라
import csv
file=open('/content/subwayfree.csv','r',encoding='cp949')
data=csv.reader(file)
next(data)

mx=-1 #mx는 max의 변수 처음부터 100으로 주면 밑에 결과가 다 작을것이기 때문에 적은 -1로 함. 예를들어 제일 작은값이면 -1이면 안됨. 
      #1000이던 내가 생각한 큰 값을 적는다.
rate=0 #rate는 변수이고  저장하는 변수명이다. 예를들어 4인덱스 + 6인덱스 분에 4인덱스를 저장하는 공간이 rate라는 것임.
mx_station=''

for row in data:
  for i in range(4,8): # 엑셀에는 써있는것이 숫자가 아니니까 첫번째부터 0번 1번 2번 이런식으로 생각해야함.
    row[i]=int(row[i])
  if(row[6]==0 and row[4]+row[6]<100000): #만약에 6번째 인덱스가 6이 0이면 그냥 넘어가라 또 4번, 6번 인덱스가 100000보다 작으면 다음으로 넘어가라.
   continue
  rate=row[4]/(row[4]+row[6]) #예를들어 첫 번째 인덱스를 계산했는데 값이 80이 나왔다면
  if rate > mx: #바로 윗줄에서 구한 80을 rate에 대입해서 저장되어있는 최대값이랑 비교하는것.
    mx=rate #계산한 값이 최대값이면 mx에 저장되는것.
    mx_station=row[3]=''+row[1]
print(mx_station,round(mx*100,2))

# %%
#유무임 승하차 인원이 가장 많은 역은 어디일까?
import csv
file=open('/content/subwayfree.csv','r',encoding='cp949')
data=csv.reader(file)
next(data)

mx=[-1]*4 # [-1 -1 -1 -1] 이렇게 저장되어있음 각각 mx[0],mx[1],mx[2],mx[3]이렇게 저장되어있는것
mx_station=['']*4
label=['유임승차','유임하차','무임승차','무임하차']

for row in data:
  for i in range(4,8): #인덱스 4번부터 8번까지
    row[i]=int(row[i]) #인티저로 바꾸고싶음.
    if(row[i]>mx[i-4]):#row[4]>mx[0] 4번째 인덱스를 첫번째꺼랑 비교하기 위해 -4해준것임.
      mx[i-4]=row[i]
      mx_station[i-4]=row[3]+' '+row[1]

for i in range(4):
  print(label[i]+": "+mx_station[i],mx[i])

# %%
#데이터 출력해보기
import csv
file=open('/content/subwaytime.csv','r',encoding='cp949')
data=csv.reader(file)

for row in data:
  print(row)

# %%
#헤더 제외하고 map 함수를 활용한 데이터 타입 바꾸기(문자열 -> 정수)
import csv
file=open('/content/subwaytime.csv','r',encoding='cp949')
data=csv.reader(file)
next(data)
next(data)

for row in data:
  print(row)
  row[4:]=map(int,row[4:])
  print(row)
  break

# %%
#아침 7시 승차 데이터 개수 및 인원수 출력
import csv
import matplotlib.pyplot as plt

file=open('/content/subwaytime.csv','r',encoding='cp949')
data=csv.reader(file)
next(data)
next(data)
result=[]

for row in data:
  row[4:]=map(int,row[4:])
  result.append(row[10])

print(len(result))
print(result)

# %%
#출근시간(아침7~9시)승차인원 더하기
import csv
import matplotlib.pyplot as plt

file=open('/content/subwaytime.csv','r',encoding='cp949')
data=csv.reader(file)
next(data)
next(data)
result=[]

for row in data:
  row[4:]=map(int,row[4:])
  result.append(sum(row[10:15:2]))

result.sort()
plt.figure(figsize=(10,5),dpi=300)
plt.bar(range(len(result)),result)
plt.show()

# %%
#출근시간(아침 7~9시) 승차 최대역 찾기
import csv
import matplotlib.pyplot as plt

file=open('/content/subwaytime.csv','r',encoding='cp949')
data=csv.reader(file)
next(data)
next(data)
mx=-1
mx_station=''

for row in data:
  row[4:]=map(int,row[4:])
  SUM101214=sum(row[10:15:2])
  if SUM101214 >mx:
    mx=SUM101214
    mx_station=row[3]+row[1]

print(mx_station),mx

# %%
#[과제]아침 7~9시 하차 인원 최대 역 찾기
import csv
import matplotlib.pyplot as plt

file=open('/content/subwaytime.csv','r',encoding='cp949')
data=csv.reader(file)
next(data)
next(data)
mx=0
mx_station=''

for row in data:
  row[4:]=map(int,row[4:])
  SUM101214=sum(row[11:12:2])
  if SUM101214 >mx:
    mx=SUM101214
    mx_station=row[3]+row[1]

print(mx_station),mx

# %%
#밤11시 가장 많이 타는 역은?
import csv
import matplotlib.pyplot as plt

file=open('/content/subwaytime.csv','r',encoding='cp949')
data=csv.reader(file)
next(data)
next(data)
mx=-1
mx_station=''
t=11

for row in data:
  row[4:]=map(int,row[4:])
  mxpeople=row[4+(t-4)*2]
  if mxpeople > mx:
    mx=mxpeople
    mx_station=row[3]+row[1]

print(mx_station,mx)

# %%
#새벽4시~6시 최대승차 역 이름/승차 인원 출력
import csv
import matplotlib.pyplot as plt

file=open('/content/subwaytime.csv','r',encoding='cp949')
data=csv.reader(file)
next(data)
next(data)
mx=[-1]*3
mx_station=['']*3

for row in data:
  row[4:]=map(int,row[4:])
  for j in range(3):
    mumpeople=row[j*2+4]
    if(mumpeople>mx[j]):
      mx[j]=mumpeople
      mx_station[j]=row[3]

print(mx_station)
print(mx)

# %%
#모든 지하철역에서 시간대별 승하차 인원을 모두 더하면
import csv
import matplotlib.pyplot as plt
file=open('/content/subwaytime.csv','r',encoding='cp949')
data=csv.reader(file)
next(data)
next(data) #next는 시작위치를 아랫줄로 바꾸는 것. 왜 2번썼냐면 엑셀파일에 1,2줄이 글자와 공백이라

s_in=[0] * 24 #모든 지하철의 승하차를 구하는 것이니 24임.
s_out=[0] * 24

#밑에 for문 얘기임. for문 안에 for문이니까 첫번째 for문안에서 첫 번째 역을 선정함. 그 밑에 for문에서 승하차 나옴. 
#위에 for문 다돌고 끝나면 다시 위로 올라가서 첫 번째 for문으로 돌아감. 그럼 다음역 두 번째 역을 넣고 그다음 for으로 들어가서 다시 승하차를 계산함.
for row in data:
  row[4:]=map(int,row[4:]) #4번 인덱스부터 끝까지 /map함수는 괄호의 두 번째 인덱스를 int로 바꾼다는 함수
  for i in range(24): #0부터 23까지(23까지면 24로 표기)
    s_in[i]+=row[4+i*2] #첫 번째로는 0번째를 i에 집어 넣음. 계산해보면 4임. 그러면 4번째 인덱스가 s_in 즉 4번째 인덱스에 있는 4시 승차인원이 됨.
    s_out[i]+=row[5+i*2] #첫 번째끝나면 다음 인덱스에 1 들어가서 for문돌음. 그러면 s-in에는 4,6,8시 이런식으로 승차인원이 들어감. 마지막 새벽3시까지 for문 돔.

for j in range(24): #위에 문단for문에 승하차 인원이 저장되어있으니 잘 저장되어있는지 확인을 위해 넣어놓은거임. 
  print(s_in[j],s_out[j]) #숫자만 출력할거면 여기서 끝내고 그래프로 나타내면 밑에 추가

#그래프로 나타내기 위에는 숫자만 출력하는거임.
plt.title('# of passengers getting IN and OUT by time')
plt.plot(s_in,label="IN")
plt.plot(s_out,label="out")
plt.xticks(range(24),range(4,28)) #4,28은 4번째 인덱스부터 새벽3시인 27까지 표기로는 28로 표기함. 
plt.legend()
plt.show()

# %%
import pandas as pd

file_path='/content/chipotle.tsv'
chipo=pd.read_csv(file_path,sep='\t')

print(chipo.shape)
print("---------------------")
print(chipo.info())

#결과분석
#object는 일반적으로 문자형
#3번째 줄 choice_description에서 혼자만 값이 다름
#(1246=4622-3376)개는 결측값이 있음을 알 수 있어 코딩에서 뭔가 처리해야함.

# %%
#chipo 내용확인
chipo.head(10) #chipo 라는 Dataframe에서 순서대로 10개의 row데이터를 보여줌.

# %%
chipo['order_id']=chipo['order_id'].astype(str) #astype은 타입을 바꿔줌.id는 의미없으므로 문자로 바꿈.

print(chipo.describe()) #chipo의 데이터 중에 숫자로 되어있는 데이터들에 한해서 표준편차, 평균 이런게 나옴.
                        #만약 위에서 타입을 안바꿨으면 quantity말고도 order_id도 숫자이기 때문에 나왔을 것이다.
print(len(chipo['order_id'].unique())) #unique는 말 그대로 특별한 애들 즉, 음식의 종류들이 쭉 나옴 len은 길이임.
print(len(chipo['item_name'].unique())) #즉 order_id,item_name에 음식 종류가 몇개 있는지 길이를 나타냄 (1834,50)

# %%
# 가격앞에 $가 있어서 이걸 분리해야 수치적으로 확인이 가능하다
# 방법1) 엑셀같은 툴을 이용해서 삭제하는 방법
# 방법2) split 함수를 이용해서 분리하는 방법
# 방법3) 람다(lamda) 함수를 이용하는 방법(이거사용함)
#(lamde x,y:x+y)(10,20) 결과값:30 lamda함수는 :으로 기준이 나뉨. : 앞에는 입력 파라미터, : 뒤에는 결과를 리턴함.
# 그 다음 괄호에 주어질 값을 넣으면 결과값이 나옴.

import pandas as pd

filt_path='/content/chipotle.tsv'
chipo=pd.read_csv(file_path,sep='\t')

def splt_firstchar(x):
  return float(x[1:]) #float로 변경하겠다. 0번 제외하고 1번부터 float로 바꿔서 집어넣어라.
                      #예를들어 $10.0이면 0번째는 $이기 때문에 뺴야함. 
chipo['item_price']=chipo['item_price'].apply(splt_firstchar) #for문을 돌려면 기니까 apply 하나쓰면 지가 for문 돔.
#chipo['item_price]=chipo['item_price].apply(lamda x:float(x[1:])) #바로윗줄 lamda 함수로 바꾼것. 
                                                                  #x 집어넣으면 float로 바꾼 x를 리턴해줘 라는 뜻.
chipo.describe() #바뀌었는지 확인함.

# %%
import pandas as pd

file_path='/content/chipotle.tsv'
chipo=pd.read_csv(file_path,sep='\t')

item_unique=chipo['item_name'].unique()
item_count=chipo['item_name'].value_counts() #value_counts는 unique에 더해 음식의 종류와 키,값까지 나옴.

print(item_unique)
print('---------')
print(item_count)

# %%
letters=['A''B','C']

for i in range(len(letters)):
  letter=letters[i]
  print(i,letter)

print('-----------')
for entry in enumerate(['A','B','C']):
  print(entry)

print('-----------')
for i ,letter in enumerate(['A','B','C']):
  print(i,letter)

print('-----------')
for i ,letter in enumerate(['A','B','C'],start=101): #시작을 101로 하겠다. 
  print(i,letter)

# %%
#많이 팔린 음식은 뭐고, 몇 개?
import pandas as pd

file_path='/content/chipotle.tsv'
chipo=pd.read_csv(file_path,sep='\t')

item_count=chipo['item_name'].value_counts()[:10] #0~10까지, value_counts는 item_name의 value와 count를 동시에 리턴
#만약에 적게팔린 음식을 구하는 거면 윗줄 맨끝 [:10]을 예를들어 [10:]처럼 맨 밑 숫자를 적으면 됨. 
for idx,(val,cnt)in enumerate(item_count.iteritems(),1):#iteritems는 item_count에 들어가있는 키, 밸류를 리턴함.
                                                        #이것을 val, cnt에 넣음. 마지막에 1이 없었으면 0부터 시작했을것. 
  print("Top",idx,":",val,cnt)

# %%
df=pd.DataFrame({
    'city':['부산','부산','부산','부산','서울','서울','서울'],
    'fruits':['apple','orange','banana','banana','apple','apple','banana'],
    'price':[100,200,250,300,150,200,400],
    'quantity':[1,2,3,4,5,6,7]
})
df

# %%
#아이템당 주문 개수 출력(개수는 하나하나있는것을 카운트한것)
order_count=chipo.groupby('item_name').count()
#order_count=chipo.groupby('item_name')['order_id'].count() #이건 윗줄 이랑 뭐가다른지 확인해보라는 주석
order_count[:12] #상위 12개

# %%
#아이템별 주문개수와 총량(총량은 있는 것 다 더한것.)
item_quantity=chipo.groupby('item_name')['quantity'].sum() #item_name으로 그룹핑하고,[]안에 있는것을 sum하겠다.
                                                            #만약 []가 없고 item_name.count()면 숫자인 모든 항목을 셈.
item_quantity[:10]

# %%
#아이템별 주문개수와 총량
order_count=chipo.groupby("item_name").count()
#order_count=chipo.groupby('item_name')['order_id'].count() #얘는 item_id나오고 옆에 orderid만 나옴.
order_count[:12] #아이템당 주문개수 출력함. 12줄까지 출력해라.

# %%
#item당 주문 총량을 출력합니다.
item_quantity=chipo.groupby('item_name')['quantity'].sum() #item_name나오고 옆에 다필요없고 quantity 값만 보여줘라.
item_quantity[:10]

# %%
#주문당 평균 계산금액
import pandas as pd

file_path='/content/chipotle.tsv'
chipo=pd.read_csv(file_path,sep='\t')

chipo['item_price']=chipo['item_price'].apply(lambda x: float(x[1:])) #가격을 표시하기 위해 $표시 없애기 위해 lambda함수 사용

chipo.groupby('order_id')['item_price'].sum().mean() #더한값을 평균 구해라. 더하기, 평균값 둘다 나타내라는 얘기 아님.

# %%
#한 주문에 15달라 이상 지불한 주문번호 출력
import pandas as pd

file_path='/content/chipotle.tsv'
chipo=pd.read_csv(file_path,sep='\t')

chipo['item_price']=chipo['item_price'].apply(lambda x:float(x[1:]))

chipo_orderid_group=chipo.groupby('order_id').sum() #orderid별로 그룹핑하고 숫자로 되어있는 아이들은 sum해라
print(chipo_orderid_group)

results=chipo_orderid_group[chipo_orderid_group.item_price>=15]
print('---------------------')
print(results[:10])

# %%
chipo_one_item=chipo[chipo.quantity==1] #quantity를 한개 주문한 애들을 one_item함수에 넣어라.
#print(chipo_one_item)
price_per_item=chipo_one_item.groupby('item_name').min()
#print(price_per_item[:10])
price_per_item.sort_values(by='item_price',ascending=False)[:10] #ascending=False: 내림차순. ascending=True:오름차순

# %%
#가장 비싼 주문에서 아이템이 총 몇 개 팔렸나?
import pandas as pd

file_path='/content/chipotle.tsv'
chipo=pd.read_csv(file_path,sep='\t')

chipo['item_price']=chipo['item_price'].apply(lambda x:float(x[1:]))

chipo.groupby('order_id').sum().sort_values(by='item_price',ascending=False)[:5]

# %%
#Veggie Salad Bowl이 몇번 주문되었을까?
import pandas as pd

file_path='/content/chipotle.tsv'
chipo=pd.read_csv(file_path,sep='\t')

chipo_salad=chipo[chipo['item_name']=='Veggie Salad Bowl'] #아이템이름이 Veggie Salad Bowl인 것을 chipo_salad에 넣어라.

chipo_salad.head(5)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
file_path='/content/drinks.csv'
drinks=pd.read_csv(file_path)

print(drinks.info())

drinks.head(10)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
file_path='/content/drinks.csv'
drinks=pd.read_csv(file_path)

drinks.describe()#전체 개수, 평균, 표준편차 등 수치적인 통계가 나옴.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
file_path='/content/drinks.csv'
drinks=pd.read_csv(file_path)

corr=drinks[['beer_servings','wine_servings']].corr(method='pearson')
print(corr)

# %%
#상관분석
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
file_path='/content/drinks.csv'
drinks=pd.read_csv(file_path)

cols=['beer_servings','spirit_servings','wine_servings','total_litres_of_pure_alcohol']
corr=drinks[cols].corr(method='pearson')
print(corr)

# %%
#내용확인 그래프로
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
file_path='/content/drinks.csv'
drinks=pd.read_csv(file_path)

sns.set(style='whitegrid',context='notebook') #seaborn 4종류의 스케일(사이즈) notebook이 사이즈이름임.
sns.pairplot(drinks[['beer_servings','spirit_servings',
                     'wine_servings','total_litres_of_pure_alcohol']],height=2.5)
plt.show()
#결과분석
#그래프중에 모양 흐트러진것(점으로 된것)은 상관관계가 서로 없다는것!

# %%
import pandas as pd

file_path='/content/drinks.csv'
drinks=pd.read_csv(file_path)

print(drinks.isnull().sum())

#결측데이터를 처리: 기타 대륙으로 통합->'OT'
drinks['continent']=drinks['continent'].fillna('OT') #OT를 집어넣어라 
print(drinks.isnull().sum())

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path='/content/drinks.csv'
drinks=pd.read_csv(file_path)

drinks['continent']=drinks['continent'].fillna('OT') #fillna안에는 아무것도 없음. 거기다가 OT넣어라.

labels=drinks['continent'].value_counts().index.tolist() #레이블변수에 밸류와 카운트를 구해서 그 주에서 
fracs1=drinks['continent'].value_counts().values.tolist() #인덱스를 리스트로 만들어라.
explode=(0,0,0,0.25,0,0) #4번째 인덱스를 그래프에서 좀 띄워놓으라는 뜻. 

plt.pie(fracs1, explode=explode, labels=labels, autopct='%.0f%%', shadow=True) #autopct는 값을 반올림하는것
plt.title('null data to \'OT\'')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path='/content/drinks.csv'
drinks=pd.read_csv(file_path)

drinks['continent']=drinks['continent'].fillna("OT")

result=drinks.groupby('continent').spirit_servings.agg(['mean','min','max','sum'])
print(result)

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path='/content/drinks.csv'
drinks=pd.read_csv(file_path)

drinks['continent']=drinks['continent'].fillna('OT')

total_mean=drinks.total_litres_of_pure_alcohol.mean()
continent_mean=drinks.groupby('continent')['total_litres_of_pure_alcohol'].mean()
continent_over_mean=continent_mean[continent_mean>=total_mean]
print(continent_over_mean)

# %%
#전체 평균보다 많은 알코올을 섭취하는 대륙은?
import pandas as pd
import matplotlib.pyplot as plt

file_path='/content/drinks.csv'
drinks=pd.read_csv(file_path)

drinks['continent']=drinks['continent'].fillna('OT')
beer_continent=drinks.groupby('continent').beer_servings.mean().idxmax()
print(beer_continent)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

file_path='/content/drinks.csv'
drinks=pd.read_csv(file_path)

drinks['continent']=drinks['continent'].fillna('OT')

totla_mean=drinks.total_litres_of_pure_alcohol.mean()
continent_mean=drinks.groupby('continent')['total_litres_of_pure_alcohol'].mean()
continent_over_mean=continent_mean[continent_mean>=total_mean]

#대륙별 totla_litres_or_pure_alcohol을 시각화.
print(continent_mean)
continents=continent_mean.index.tolist()
print(continents)
continents.append('mean')
print(continents)
x_pos=np.arange(len(continents))#전체 컨티넌트에 개수를 넣는것. 예를들어 continents에 5있으면 x에 0~5까지 들어감.
alcohol=continent_mean.tolist()
print(alcohol)
alcohol.append(totla_mean)
print(alcohol)

# %%
#total_litres_of_pure_alcohol 시각화
continents=continent_mean.index.tolist()
continents.append('mean')
x_pos=np.arange(len(continents))
alcohol=continent_mean.tolist()
alcohol.append(totla_mean)

bar_list=plt.bar(x_pos,alcohol,align='center',alpha=0.5) #alpha값은 투명도를 나타냄.
plt.xticks(x_pos,continents) #xticks는 대륙이름이 나오게 해줌.(가로)없으면 0,1,2 이런식으로 나옴.
plt.ylabel('tolta_litres_of_pure_alcohol')
plt.title('total_litres_of_pure_alcohol by Continent')

plt.show()

# %%
#시각화 좀 더 이쁘게 
continents=continent_mean.index.tolist()
continents.append('mean')
x_pos=np.arange(len(continents))
alcohol=continent_mean.tolist()
alcohol.append(totla_mean)

bar_list=plt.bar(x_pos,alcohol,align='center',alpha=0.5) #alpha값은 투명도를 나타냄.
bar_list[len(continents)-1].set_color('r')#맨끝의 색을 레드로 바꿔라
plt.plot([0,len(continents)-1],[total_mean,total_mean],"k--") #선을 긋는것. 색은 블랙, --모양으로 그려라
plt.xticks(x_pos,continents) #xticks는 대륙이름이 나오게 해줌.(가로)없으면 0,1,2 이런식으로 나옴.
plt.ylabel('tolta_litres_of_pure_alcohol')
plt.title('total_litres_of_pure_alcohol by Continent')

plt.show()

# %%
#우리나라 몇위?
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

file_path='/content/drinks.csv'
drinks=pd.read_csv(file_path)

drinks['continent']=drinks['continent'].fillna('OT')

#total_servings 피처를 생성, 마지막 열에 생성됨 #엑셀 파일 마지막 열에 total_servings라는 칸이 따로 생김.
drinks['total_servings']=drinks['beer_servings']+drinks['wine_servings']+drinks['spirit_servings']

#술 소비량 대비 알콜 비율 피처를 생성 #엑셀 파일 마지막 열에 alcohol_rate이라는칸이 따로 생김.
drinks['alcohol_rate']=drinks['total_litres_of_pure_alcohol']/drinks['total_servings']

#결측값을 0으로 #알코올을 아예안먹는 나라가 있으면 분모가 0이 되므로 결측값이 있으면 0으로 채워라.
drinks['alcohol_rate']=drinks['alcohol_rate'].fillna(0)

#순위 정보를 생성
country_with_rank=drinks[['country','alcohol_rate']]
country_with_rank=country_with_rank.sort_values(by=['alcohol_rate'],ascending=0)
country_with_rank.head(5)

# %%
#우리나라 몇위?가시화
country_list=country_with_rank.country.tolist()
x_pos=np.arange(len(country_list))
rank=country_with_rank.alcohol_rate.tolist()

bar_list=plt.bar(x_pos,rank)
plt.ylabel('alcohol rate')
plt.title('liquor drink rank by contry')
plt.axis([1,200,0,0.3]) #axis는 x축, y축의 값을 최대 최소 얼마를 주겠다는 함수
plt.show()

# %% [markdown]
# 6주차 43p. 7번째 줄 continent에 국가명이 몇개 빠져있어서 fillna로 채워라
# 내가 만든 변수 ot로
# loc():는 행 데이터를 조회하는것.

# %%
country_list=country_with_rank.country.tolist()
x_pos=np.arange(len(country_list))
rank=country_with_rank.alcohol_rate.tolist()

bar_list=plt.bar(x_pos,rank)
plt.ylabel('alcohol rate')
plt.title('liquor drink rank by contry')
plt.axis([1,200,0,0.3]) #axis는 x축, y축의 값을 최대 최소 얼마를 주겠다는 함수

bar_list[country_list.index("South Korea")].set_color('r') #한국이 속하는 곳의색을 빨간색으로 바꿔라

korea_rank=country_list.index("South Korea")
korea_alc_rate=country_with_rank[country_with_rank['country']=='South Korea']['alcohol_rate'].values[0]

plt.annotate('South Korea: '+str(korea_rank+1), #글자 넣는것
             xy=(korea_rank, korea_alc_rate), #xy는 화살표를 가르킬 위치
             xytext=(korea_rank+10, korea_alc_rate+0.05),#글씨를 어느 위치에 찍을까
             arrowprops=dict(facecolor='red', shrink=0.05))#텍스트로부터 화살표가 얼만큼 떨어지는곳에서 시작해야하나
                                                          #그래프 끝과 화살표의 끝을 값을 0.05로 줘라 이거 안하면 그래프에 화살표 바로 붙음
plt.show()

# %%
#서울에서 경기도로 이동한 인구데이터를 그려본다.
import pandas as pd
import matplotlib.pyplot as plt
import warnings #워닝은 무시해라.
warnings.simplefilter("ignore")

#엑셀 데이터를 데이터프레임 변환
file_path='/content/inoutpeople.xlsx'
df=pd.read_excel(file_path,engine='openpyxl',header=0)

df.head()
# Out:
#    전출지별   전입지별       1970       1971       1972       1973       1974  \
# 0  전출지별   전입지별   이동자수 (명)   이동자수 (명)   이동자수 (명)   이동자수 (명)   이동자수 (명)
# 1    전국     전국  4046536.0  4210164.0  3687938.0  4860418.0  5297969.0
# 2   NaN  서울특별시  1742813.0  1671705.0  1349333.0  1831858.0  2050392.0
# 3   NaN  부산광역시   448577.0   389797.0   362202.0   482061.0   680984.0
# 4   NaN  대구광역시          -          -          -          -          -
#
#         1975       1976       1977  ...       2008       2009       2010  \
# 0   이동자수 (명)   이동자수 (명)   이동자수 (명)  ...   이동자수 (명)   이동자수 (명)   이동자수 (명)
# 1  9011440.0  6773250.0  7397623.0  ...  8808256.0  8487275.0  8226594.0
# 2  3396662.0  2756510.0  2893403.0  ...  2025358.0  1873188.0  1733015.0
# 3   805979.0   724664.0   785117.0  ...   514502.0   519310.0   519334.0
# 4          -          -          -  ...   409938.0   398626.0   370817.0
#
#         2011       2012       2013       2014       2015       2016       2017
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings 
warnings.simplefilter("ignore")

file_path='/content/inoutpeople.xlsx'
df=pd.read_excel(file_path,engine='openpyxl',header=0)

df=df.fillna(method='ffill') #fillna=채워넣어라 ffill= 누락되어있는 값을 바로 앞에 데이터로 표시해라.(바로 앞 데이터 가져와라)

df.head()
# Out:
#    전출지별   전입지별       1970       1971       1972       1973       1974  \
# 0  전출지별   전입지별   이동자수 (명)   이동자수 (명)   이동자수 (명)   이동자수 (명)   이동자수 (명)
# 1    전국     전국  4046536.0  4210164.0  3687938.0  4860418.0  5297969.0
# 2    전국  서울특별시  1742813.0  1671705.0  1349333.0  1831858.0  2050392.0
# 3    전국  부산광역시   448577.0   389797.0   362202.0   482061.0   680984.0
# 4    전국  대구광역시          -          -          -          -          -
#
#         1975       1976       1977  ...       2008       2009       2010  \
# 0   이동자수 (명)   이동자수 (명)   이동자수 (명)  ...   이동자수 (명)   이동자수 (명)   이동자수 (명)
# 1  9011440.0  6773250.0  7397623.0  ...  8808256.0  8487275.0  8226594.0
# 2  3396662.0  2756510.0  2893403.0  ...  2025358.0  1873188.0  1733015.0
# 3   805979.0   724664.0   785117.0  ...   514502.0   519310.0   519334.0
# 4          -          -          -  ...   409938.0   398626.0   370817.0
#
#         2011       2012       2013       2014       2015       2016       2017
# ...

# %%
#서울에서 경기도로 이동한 인구
import pandas as pd
import matplotlib.pyplot as plt
import warnings 
warnings.simplefilter("ignore")

file_path='/content/inoutpeople.xlsx'
df=pd.read_excel(file_path,engine='openpyxl',header=0)

df=df.fillna(method='ffill')
#서울에서 다른 지역으로 이동한 데이터만 추출하여 정리
mask=(df['전출지별']=='서울특별시')&(df['전입지별']!='서울특별시')

#true인 부분만 df_seoul에 저장, 즉 서울에서 다른 지역으로 전출 하는 데이터만
df_seoul=df[mask] #true인 애들만 df_seoul에 저장된다.

#필요없으니 버리고
df_seoul=df_seoul.drop(['전출지별'],axis=1)

#inplace=True,df_seoul을 바꿔라 false이면 연결된 df_seoul가 바뀌지 않고 객체에 할당해줘야함
df_seoul.rename({'전입지별':'전입지'},axis=1,inplace=True)

#'전입지'가 df_seoul의 행인덱스로 지정
df_seoul.set_index('전입지',inplace=True)

#서울에서 경기도로 이동한 인구 데이터 값만 선택, loc -->열선택
sr_one=df_seoul.loc['경기도']
print(sr_one)

#x,y축 데이터를 plot함수에 입력
plt.plot(sr_one.index,sr_one.values)
plt.rc('font',family='NanumBarunGothic')
# Out:
# 1970    130149.0
# 1971    150313.0
# 1972     93333.0
# 1973    143234.0
# 1974    149045.0
# 1975    253705.0
# 1976    202276.0
# 1977    207722.0
# 1978    237684.0
# 1979    278411.0
# 1980    297539.0
# 1981    252073.0
# 1982    320174.0
# 1983    400875.0
# 1984    352238.0
# 1985    390265.0
# 1986    412535.0
# 1987    405220.0
# 1988    415174.0
# 1989    412933.0
# 1990    473889.0
# 1991    384714.0
# 1992    428344.0
# 1993    502584.0
# 1994    542204.0
# 1995    599411.0
# 1996    520566.0
# 1997    495454.0
# 1998    407050.0
# 1999    471841.0
# 2000    435573.0
# 2001    499575.0
# 2002    516765.0
# 2003    457656.0
# 2004    400206.0
# 2005    414621.0
# 2006    449632.0
# 2007    431637.0
# 2008    412408.0
# 2009    398282.0
# 2010    410735.0
# 2011    373771.0
# 2012    354135.0
# 2013    340801.0
# 2014    332785.0
# 2015    359337.0
# 2016    370760.0
# 2017    342433.0
# Name: 경기도, dtype: object

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
#서울에서 경기도로 이동한 인구
sr_one=df_seoul.loc['경기도']
#스타일 서식 지정
plt.style.use('ggplot')
#그림 사이즈 지정
plt.figure(figsize=(14,5))
#x축 눈금 라벨 회전하기
plt.xticks(size=10,rotation='vertical')

#x,y축 데이터를 plot함수에 입력, 원모양의 사이즈 10짜리 점
plt.plot(sr_one.index,sr_one.values,marker='o',markersize=10)

#차트 제목, 축이름
plt.rc('font',family='NanumBarunGothic')
plt.title('서울->경기 인구 이동')
plt.xlabel('기간')
plt.ylabel('이동 인구수')
plt.show()

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
#스타일 서식 지정
plt.style.use('ggplot')

#그래프 객체 생성(fogure에 2개의 서브 플롯을 생성)
fig=plt.figure(figsize=(10,10))
ax1=fig.add_subplot(2,1,1) #2x1로 나누고,  그 중에 첫 번째
ax2=fig.add_subplot(2,1,2) #2x1로 나누고, 그 중에 두 번째

#axe객체에 plot함수로 그래프 출력
ax1.plot(sr_one,'o',markersize=10)
ax2.plot(sr_one,marker='o',markerfacecolor='green',markersize=10,
         color='olive',linewidth=2,label='서울 -> 경기')
ax2.legend(loc='best')

#y축 범위 지정(최소값, 최대값)
ax1.set_ylim(50000,800000)
ax2.set_ylim(50000,800000)

#축 눈금 라벨 지정 및 75도 회전
ax1.set_xticklabels(sr_one.index,rotation=75)
ax2.set_xticklabels(sr_one.index,rotation=75)

#축 이름 추가
ax1.set_xlabel('기간',size=20)
ax1.set_ylabel('이동 인구수',size=12)
ax2.set_xlabel('기간',size=12)
ax2.set_ylabel('이동 인구수',size=12)

#축 눈금 라벨 크기
ax1.tick_params(axis="x",labelsize=15)
ax1.tick_params(axis="y",labelsize=15)
ax2.tick_params(axis="x",labelsize=5)
ax2.tick_params(axis="y",labelsize=5)

plt.show()

# %%
#서울에서 충청남도, 경상북도, 강원도로 이동한 인구 데이터 값만 선택
df_3=df_seoul.loc[['충청남도','경상북도','강원도']]
print(df_3)

#스타일 서식 지정
plt.style.use('ggplot')

#그래프 객체 생성 (figure에 1개의 서브 플롯을 생성)
fig=plt.figure(figsize=(20,5))
ax=fig.add_subplot(1,1,1)

#axe객체에 plot함수로 그래프 출력
col_years=list(map(str,range(1970,2018)))
ax.plot(col_years,df_3.loc['충청남도',:],marker='o',markerfacecolor='green',
        markersize=10,color='olive',linewidth=2,label='서울 -> 충남')
ax.plot(col_years,df_3.loc['경상북도',:],marker='o',markerfacecolor='blue',
        markersize=10,color='skyblue',linewidth=2,label='서울 ->경북')
ax.plot(col_years,df_3.loc['강원도',:],marker='o',markerfacecolor='red',
        markersize=10,color='magenta',linewidth=2,label='서울 -> 강원')

#범례 표시
ax.legend(loc='best')

#차트 제목 추가
ax.set_title('서울 -> 충남, 경북, 강원 인구 이동',size=20)

#축이름 추가
ax.set_xlabel('기간',size=12)
ax.set_ylabel('이동 인구수',size=12)

#축 눈금 라벨 지정 및 90도 회전
ax.set_xticklabels(col_years,rotation=90)

#축 눈금 라벨 크기
ax.tick_params(axis="x",labelsize=10)
ax.tick_params(axis="y",labelsize=10)

plt.show()
# Out:
#          1970     1971     1972     1973     1974     1975     1976     1977  \
# 전입지
# 충청남도  15954.0  18943.0  23406.0  27139.0  25509.0  51205.0  41447.0  43993.0
# 경상북도  11868.0  16459.0  22073.0  27531.0  26902.0  46177.0  40376.0  41155.0
# 강원도    9352.0  12885.0  13561.0  16481.0  15479.0  27837.0  25927.0  25415.0
#
#          1978     1979  ...     2008     2009     2010     2011     2012  \
# 전입지                     ...
# 충청남도  48091.0  45388.0  ...  27458.0  24889.0  24522.0  24723.0  22269.0
# 경상북도  42940.0  43565.0  ...  15425.0  16569.0  16042.0  15818.0  15191.0
# 강원도   26700.0  27599.0  ...  23668.0  23331.0  22736.0  23624.0  22332.0
#
#          2013     2014     2015     2016     2017
# 전입지
# 충청남도  21486.0  21473.0  22299.0  21741.0  21020.0
# 경상북도  14420.0  14456.0  15113.0  14236.0  12464.0
# 강원도   20601.0  21173.0  22659.0  21590.0  21016.0
#
# [3 rows x 48 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings 
warnings.simplefilter("ignore")

file_path='/content/inoutpeople.xlsx'
df=pd.read_excel(file_path,engine='openpyxl',header=0)

df=df.fillna(method='ffill')

#서울에서 다른 지역으로 이동한 데이터만 추출하여 정리
mask=(df['전출지별']=='서울특별시')&(df['전입지별']!='서울특별시')
df_seoul=df[mask]
df_seoul=df_seoul.drop(['전출지별'],axis=1)
df_seoul.rename({'전입지별':'전입지'},axis=1,inplace=True)
df_seoul.set_index('전입지',inplace=True)

#서울에서 충청남도, 경상북도, 강원도 전라남도 로 이동한 인구 데이터 값만 선택
df_4=df_seoul.loc[['충청남도','경상북도','강원도','전라남도']]
df_4=df_4.transpose()

#스타일 서식 지정
plt.style.use('ggplot')

df_4.index=df_4.index.map(int)

#면적 그래프 그리기
df_4.plot(kind='area',stacked=True, alpha=0.2,figsize=(20,10))

plt.title('서울 -> 타시도 인구 이동',size=30,color='brown',weight='bold')
plt.ylabel('이동 인구 수',size=20,color='blue')
plt.xlabel('기간',size=20,color='blue')
plt.legend(loc='best',fontsize=15)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings 
warnings.simplefilter("ignore")

file_path='/content/inoutpeople.xlsx'
df=pd.read_excel(file_path,engine='openpyxl',header=0)

df=df.fillna(method='ffill')

#서울에서 다른 지역으로 이동한 데이터만 추출하여 정리
mask=(df['전출지별']=='서울특별시')&(df['전입지별']!='서울특별시')
df_seoul=df[mask]
df_seoul=df_seoul.drop(['전출지별'],axis=1)
df_seoul.rename({'전입지별':'전입지'},axis=1,inplace=True)
df_seoul.set_index('전입지',inplace=True)

#서울에서 충청남도, 경상북도, 강원도, 전라남도로 이동한 인구 데이터 값만 선택
#col_year에 해당하는 부분만 df_4에 저장후 transpose
col_years=list(map(str,range(2010,2018)))
df_4=df_seoul.loc[['충청남도','경상북도','강원도','전라남도'],col_years]
df_4=df_4.transpose()

plt.style.use('ggplot')

#데이터프레임의 인덱스를 정수형으로 변경
df_4.index=map(int,df_4.index)

#막대 그래프 그리기
df_4.plot(kind='bar',figsize=(20,10),width=0.7,color=['orange','green','skyblue','blue'])

plt.title('서울 -> 타시도 인구 이동',size=30)
plt.ylabel('이동 인구 수',size=30)
plt.xlabel('기간',size=20)
plt.ylim(5000,30000)
plt.legend(loc='best',fontsize=15)
plt.rc('font',family='NanumBarunGothic')
plt.show()

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# The following packages were automatically installed and are no longer required:
#   libnvidia-common-460 nsight-compute-2020.2.0
# Use 'sudo apt autoremove' to remove them.
# 0 upgraded, 0 newly installed, 0 to remove and 42 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# ...

# %%
#9주차 과제
import pandas as pd
import matplotlib.pyplot as plt
import warnings 
warnings.simplefilter("ignore")

file_path='/content/inoutpeople.xlsx'
df=pd.read_excel(file_path,engine='openpyxl',header=0)
col_years = list(map(str, range(1970, 2018)))
df4 = df_seoul.loc[['충청남도', '경상북도', '강원도', '전라남도'],col_years]

plt.style.use('ggplot')
fig = plt.figure(figsize = (20,10))
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

ax1.plot(col_years, df4.loc['충청남도',:], marker = 'o', markerfacecolor = 'green', markersize = 10, color = 'olive', linewidth = 2, label='서울 -> 충남')
ax2.plot(col_years, df4.loc['경상북도',:], marker = 'o', markerfacecolor = 'red', markersize = 10, color = 'hotpink', linewidth = 2, label='서울 -> 경북')
ax3.plot(col_years, df4.loc['강원도',:], marker = 'o', markerfacecolor = 'blue', markersize = 10, color = 'skyblue', linewidth = 2, label='서울 -> 강원')
ax4.plot(col_years, df4.loc['전라남도',:], marker = 'o', markerfacecolor = 'orange', markersize = 10, color = 'yellow', linewidth = 2, label='서울 -> 전남')

ax1.legend(loc = 'best')
ax2.legend(loc = 'best')
ax3.legend(loc = 'best')
ax4.legend(loc = 'best')

ax1.set_title('서울 -> 충남 인구 이동', size = 15)
ax2.set_title('서울 -> 경북 인구 이동', size = 15)
ax3.set_title('서울 -> 강원 인구 이동', size = 15)
ax4.set_title('서울 -> 전남 인구 이동', size = 15)
plt.show()
